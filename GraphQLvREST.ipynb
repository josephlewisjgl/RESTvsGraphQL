# %% [markdown]
# # Notebook to explore the use of GraphQL vs REST APIs
#
# To compare the use of GraphQL and REST APIs this notebook will query the Disney Character API which has an implentation of each.

# %%
import requests
import pandas as pd
import pyodbc
import json
import time
import re

# %% [markdown]
# ## REST API Implementation
#
# The more commonly used REST API is implemented.

# %%
endpoint = 'https://api.disneyapi.dev/characters/'
all_data = []
has_next_page = True
page_no = 0

while has_next_page:
    req = requests.get(endpoint)
    
    if req.status_code == 200:
        character_data = req.json().get('data')
        character_data = pd.DataFrame(character_data)
        character_data = character_data[['_id',
          'url',
          'name',
          'imageUrl',
          'allies',
          'enemies']]
        
        all_data.append(character_data)
        
        time.sleep(3)
        
        page_no += 1

        if req.json().get('nextPage') is None:
            has_next_page = False
        else:
            endpoint = req.json().get('nextPage')

        print(f'Page: {page_no} Successful: {req.status_code}')
    else:
        print(f'Page: {page_no} Failed: {req.status_code}')
        
all_data = pd.concat(all_data)
all_data.to_csv('rest.csv')
# Out:
# Page: 1 Successful: 200
# Page: 2 Successful: 200
# Page: 3 Successful: 200
# Page: 4 Successful: 200
# Page: 5 Successful: 200
# Page: 6 Successful: 200
# Page: 7 Successful: 200
# Page: 8 Successful: 200
# Page: 9 Successful: 200
# Page: 10 Successful: 200
# Page: 11 Successful: 200
# Page: 12 Successful: 200
# Page: 13 Successful: 200
# Page: 14 Successful: 200
# Page: 15 Successful: 200
# Page: 16 Successful: 200
# Page: 17 Successful: 200
# Page: 18 Successful: 200
# Page: 19 Successful: 200
# Page: 20 Successful: 200
# Page: 21 Successful: 200
# Page: 22 Successful: 200
# Page: 23 Successful: 200
# Page: 24 Successful: 200
# Page: 25 Successful: 200
# Page: 26 Successful: 200
# Page: 27 Successful: 200
# Page: 28 Successful: 200
# Page: 29 Successful: 200
# Page: 30 Successful: 200
# Page: 31 Successful: 200
# Page: 32 Successful: 200
# Page: 33 Successful: 200
# Page: 34 Successful: 200
# Page: 35 Successful: 200
# Page: 36 Successful: 200
# Page: 37 Successful: 200
# Page: 38 Successful: 200
# Page: 39 Successful: 200
# Page: 40 Successful: 200
# Page: 41 Successful: 200
# Page: 42 Successful: 200
# Page: 43 Successful: 200
# Page: 44 Successful: 200
# Page: 45 Successful: 200
# Page: 46 Successful: 200
# Page: 47 Successful: 200
# Page: 48 Successful: 200
# Page: 49 Successful: 200
# Page: 50 Successful: 200
# Page: 51 Successful: 200
# Page: 52 Successful: 200
# Page: 53 Successful: 200
# Page: 54 Successful: 200
# Page: 55 Successful: 200
# Page: 56 Successful: 200
# Page: 57 Successful: 200
# Page: 58 Successful: 200
# Page: 59 Successful: 200
# Page: 60 Successful: 200
# Page: 61 Successful: 200
# Page: 62 Successful: 200
# Page: 63 Successful: 200
# Page: 64 Successful: 200
# Page: 65 Successful: 200
# Page: 66 Successful: 200
# Page: 67 Successful: 200
# Page: 68 Successful: 200
# Page: 69 Successful: 200
# Page: 70 Successful: 200
# Page: 71 Successful: 200
# Page: 72 Successful: 200
# Page: 73 Successful: 200
# Page: 74 Successful: 200
# Page: 75 Successful: 200
# Page: 76 Successful: 200
# Page: 77 Successful: 200
# Page: 78 Successful: 200
# Page: 79 Successful: 200
# Page: 80 Successful: 200
# Page: 81 Successful: 200
# Page: 82 Successful: 200
# Page: 83 Successful: 200
# Page: 84 Successful: 200
# Page: 85 Successful: 200
# Page: 86 Successful: 200
# Page: 87 Successful: 200
# Page: 88 Successful: 200
# Page: 89 Successful: 200
# Page: 90 Successful: 200
# Page: 91 Successful: 200
# Page: 92 Successful: 200
# Page: 93 Successful: 200
# Page: 94 Successful: 200
# Page: 95 Successful: 200
# Page: 96 Successful: 200
# Page: 97 Successful: 200
# Page: 98 Successful: 200
# Page: 99 Successful: 200
# Page: 100 Successful: 200
# Page: 101 Successful: 200
# Page: 102 Successful: 200
# Page: 103 Successful: 200
# Page: 104 Successful: 200
# Page: 105 Successful: 200
# Page: 106 Successful: 200
# Page: 107 Successful: 200
# Page: 108 Successful: 200
# Page: 109 Successful: 200
# Page: 110 Successful: 200
# Page: 111 Successful: 200
# Page: 112 Successful: 200
# Page: 113 Successful: 200
# Page: 114 Successful: 200
# Page: 115 Successful: 200
# Page: 116 Successful: 200
# Page: 117 Successful: 200
# Page: 118 Successful: 200
# Page: 119 Successful: 200
# Page: 120 Successful: 200
# Page: 121 Successful: 200
# Page: 122 Successful: 200
# Page: 123 Successful: 200
# Page: 124 Successful: 200
# Page: 125 Successful: 200
# Page: 126 Successful: 200
# Page: 127 Successful: 200
# Page: 128 Successful: 200
# Page: 129 Successful: 200
# Page: 130 Successful: 200
# Page: 131 Successful: 200
# Page: 132 Successful: 200
# Page: 133 Successful: 200
# Page: 134 Successful: 200
# Page: 135 Successful: 200
# Page: 136 Successful: 200
# Page: 137 Successful: 200
# Page: 138 Successful: 200
# Page: 139 Successful: 200
# Page: 140 Successful: 200
# Page: 141 Successful: 200
# Page: 142 Successful: 200
# Page: 143 Successful: 200
# Page: 144 Successful: 200
# Page: 145 Successful: 200
# Page: 146 Successful: 200
# Page: 147 Successful: 200
# Page: 148 Successful: 200
# Page: 149 Successful: 200

# %%
rest_df.head()
# Out:
#   films shortFilms                               tvShows  \
# 0    []         []                                    []
# 1    []         []                       [Gravity Falls]
# 2    []         []  [Lilo & Stitch: The Series, Stitch!]
# 3    []         []                                    []
# 4    []         []                   [Pickle and Peanut]
#
#                   videoGames   parkAttractions allies enemies  _id  \
# 0                         []                []     []      []    6
# 1                         []                []     []      []    7
# 2  [Disney Tsum Tsum (game)]                []     []      []   10
# 3                         []  [The Timekeeper]     []      []   11
# 4                         []                []     []      []   12
#
#                   name                                           imageUrl  \
# 0             'Olu Mel  https://static.wikia.nocookie.net/disney/image...
# 1             .GIFfany  https://static.wikia.nocookie.net/disney/image...
# 2                  627  https://static.wikia.nocookie.net/disney/image...
# 3                9-Eye  https://static.wikia.nocookie.net/disney/image...
# 4  90's Adventure Bear  https://static.wikia.nocookie.net/disney/image...
#
#                                        url
# 0   https://api.disneyapi.dev/characters/6
# 1   https://api.disneyapi.dev/characters/7
# 2  https://api.disneyapi.dev/characters/10
# 3  https://api.disneyapi.dev/characters/11
# 4  https://api.disneyapi.dev/characters/12

# %% [markdown]
# ## GraphQL Query Structure
#
# A GraphQL query is similar to a SQL query where you can ask for different elements from a central resource base. (It is not a replacement for SQL!)

# %%
# set up endpoint and query
graph_query = '''{
  characters(page: XXX) {
    items {
      _id
      url
      name
      imageUrl
      alignment
      allies
      enemies
    }
    paginationInfo {
      hasNextPage
    }
  }
}'''

base_url = 'https://api.disneyapi.dev/graphql/'

# %%
# start at page 0 and begin querying each entity that is needed
page_no = 0
has_next_page = True
all_data = []
while has_next_page:
    req = requests.post(base_url, json={'query': re.sub('XXX', str(page_no), graph_query)})
    
    if req.status_code == 200:
        data = req.json().get('data').get('characters')
        character_data = data.get('items')
        pagination_info = data.get('paginationInfo')
        has_next_page = pagination_info.get('hasNextPage')

        character_data = pd.DataFrame(character_data)
        all_data.append(character_data)

        page_no += 1

        time.sleep(3)
        print(f'Page: {page_no} Successful: {req.status_code}')
    else:
        print(f'Page: {page_no} Failed: {req.status_code}')

all_data = pd.concat(all_data)
all_data.to_csv('graph.csv')
# Out:
# Page: 1 Successful: 200
# Page: 2 Successful: 200
# Page: 3 Successful: 200
# Page: 4 Successful: 200
# Page: 5 Successful: 200
# Page: 6 Successful: 200
# Page: 7 Successful: 200
# Page: 8 Successful: 200
# Page: 9 Successful: 200
# Page: 10 Successful: 200
# Page: 11 Successful: 200
# Page: 12 Successful: 200
# Page: 13 Successful: 200
# Page: 14 Successful: 200
# Page: 15 Successful: 200
# Page: 16 Successful: 200
# Page: 17 Successful: 200
# Page: 18 Successful: 200
# Page: 19 Successful: 200
# Page: 20 Successful: 200
# Page: 21 Successful: 200
# Page: 22 Successful: 200
# Page: 23 Successful: 200
# Page: 24 Successful: 200
# Page: 25 Successful: 200
# Page: 26 Successful: 200
# Page: 27 Successful: 200
# Page: 28 Successful: 200
# Page: 29 Successful: 200
# Page: 30 Successful: 200
# Page: 31 Successful: 200
# Page: 32 Successful: 200
# Page: 33 Successful: 200
# Page: 34 Successful: 200
# Page: 35 Successful: 200
# Page: 36 Successful: 200
# Page: 37 Successful: 200
# Page: 38 Successful: 200
# Page: 39 Successful: 200
# Page: 40 Successful: 200
# Page: 41 Successful: 200
# Page: 42 Successful: 200
# Page: 43 Successful: 200
# Page: 44 Successful: 200
# Page: 45 Successful: 200
# Page: 46 Successful: 200
# Page: 47 Successful: 200
# Page: 48 Successful: 200
# Page: 49 Successful: 200
# Page: 50 Successful: 200
# Page: 51 Successful: 200
# Page: 52 Successful: 200
# Page: 53 Successful: 200
# Page: 54 Successful: 200
# Page: 55 Successful: 200
# Page: 56 Successful: 200
# Page: 57 Successful: 200
# Page: 58 Successful: 200
# Page: 59 Successful: 200
# Page: 60 Successful: 200
# Page: 61 Successful: 200
# Page: 62 Successful: 200
# Page: 63 Successful: 200
# Page: 64 Successful: 200
# Page: 65 Successful: 200
# Page: 66 Successful: 200
# Page: 67 Successful: 200
# Page: 68 Successful: 200
# Page: 69 Successful: 200
# Page: 70 Successful: 200
# Page: 71 Successful: 200
# Page: 72 Successful: 200
# Page: 73 Successful: 200
# Page: 74 Successful: 200
# Page: 75 Successful: 200
# Page: 76 Successful: 200
# Page: 77 Successful: 200
# Page: 78 Successful: 200
# Page: 79 Successful: 200
# Page: 80 Successful: 200
# Page: 81 Successful: 200
# Page: 82 Successful: 200
# Page: 83 Successful: 200
# Page: 84 Successful: 200
# Page: 85 Successful: 200
# Page: 86 Successful: 200
# Page: 87 Successful: 200
# Page: 88 Successful: 200
# Page: 89 Successful: 200
# Page: 90 Successful: 200
# Page: 91 Successful: 200
# Page: 92 Successful: 200
# Page: 93 Successful: 200
# Page: 94 Successful: 200
# Page: 95 Successful: 200
# Page: 96 Successful: 200
# Page: 97 Successful: 200
# Page: 98 Successful: 200
# Page: 99 Successful: 200
# Page: 100 Successful: 200
# Page: 101 Successful: 200
# Page: 102 Successful: 200
# Page: 103 Successful: 200
# Page: 104 Successful: 200
# Page: 105 Successful: 200
# Page: 106 Successful: 200
# Page: 107 Successful: 200
# Page: 108 Successful: 200
# Page: 109 Successful: 200
# Page: 110 Successful: 200
# Page: 111 Successful: 200
# Page: 112 Successful: 200
# Page: 113 Successful: 200
# Page: 114 Successful: 200
# Page: 115 Successful: 200
# Page: 116 Successful: 200
# Page: 117 Successful: 200
# Page: 118 Successful: 200
# Page: 119 Successful: 200
# Page: 120 Successful: 200
# Page: 121 Successful: 200
# Page: 122 Successful: 200
# Page: 123 Successful: 200
# Page: 124 Successful: 200
# Page: 125 Successful: 200
# Page: 126 Successful: 200
# Page: 127 Successful: 200
# Page: 128 Successful: 200
# Page: 129 Successful: 200
# Page: 130 Successful: 200
# Page: 131 Successful: 200
# Page: 132 Successful: 200
# Page: 133 Successful: 200
# Page: 134 Successful: 200
# Page: 135 Successful: 200
# Page: 136 Successful: 200
# Page: 137 Successful: 200
# Page: 138 Successful: 200
# Page: 139 Successful: 200
# Page: 140 Successful: 200
# Page: 141 Successful: 200
# Page: 142 Successful: 200
# Page: 143 Successful: 200
# Page: 144 Successful: 200
# Page: 145 Successful: 200
# Page: 146 Successful: 200
# Page: 147 Successful: 200
# Page: 148 Successful: 200
# Page: 149 Successful: 200
# Page: 150 Successful: 200

# %%
graph_df.head()
# Out:
#    _id                                      url                 name  \
# 0    6   https://api.disneyapi.dev/characters/6             'Olu Mel
# 1    7   https://api.disneyapi.dev/characters/7             .GIFfany
# 2   10  https://api.disneyapi.dev/characters/10                  627
# 3   11  https://api.disneyapi.dev/characters/11                9-Eye
# 4   12  https://api.disneyapi.dev/characters/12  90's Adventure Bear
#
#                                            sourceUrl  \
# 0          https://disney.fandom.com/wiki/%27Olu_Mel
# 1            https://disney.fandom.com/wiki/.GIFfany
# 2                 https://disney.fandom.com/wiki/627
# 3               https://disney.fandom.com/wiki/9-Eye
# 4  https://disney.fandom.com/wiki/90%27s_Adventur...
#
#                                             imageUrl alignment
# 0  https://static.wikia.nocookie.net/disney/image...      None
# 1  https://static.wikia.nocookie.net/disney/image...      None
# 2  https://static.wikia.nocookie.net/disney/image...      None
# 3  https://static.wikia.nocookie.net/disney/image...      None
# 4  https://static.wikia.nocookie.net/disney/image...      None
